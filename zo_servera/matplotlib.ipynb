# %%
#modul matplotlib
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Priklad 1 
x = [2,8,13,14,17]
y = [11,-2,4,6,-5]
plt.plot(x,y)

# %%
plt.plot(x,y,'r*')
plt.grid()

# %%
x = np.linspace(-3,5,100)
y = x*np.exp(-x)
plt.plot(x,y)

# %%
x = np.linspace(-3,5,100)
y = np.cos(x)#x*np.exp(-x)
y2 = np.sin(x)
plt.plot(x,y,x,y2)
